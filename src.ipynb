# %%
import matplotlib.pyplot as plt

# %%
src_system = ['ATCKCOMP','BAI','BT','BTREE_BT10','B_FDR_PPWC','FDR_PPWC','MAAT','OCA','SDA','SDAD','TMP1BTFAIR']
values =  [  11 ,18 ,105 , 152 , 407 ,9912 , 8536 ,141,726,4,8536 ]
plt.barh(src_system,values)
# Out:
# <BarContainer object of 11 artists>
